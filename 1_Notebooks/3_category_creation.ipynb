# %% [markdown]
# # Create product categories
#
# The main objective of this project is to use data to define a pricing strategy concerning discounts. However, the analysis of a numerical variable (**product prices**) is highly enriched by the presence of a meaningful categorical variable by which data can be sliced, filtered and grouped. This categorical variable is going to be **product categories**.

# %% [markdown]
# We first need to import the Pandas module:

# %%
import pandas as pd

# %% [markdown]
# To create product categories, we use the cleaned products DataFrame.

# %%
# products_cl.csv
url = "https://drive.google.com/file/d/1b9MQQa_NRUiIiGgM7-BVznXgTYePkeZ6/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
products_cl = pd.read_csv(path)

# %%
product_category_df = products_cl.copy()

# %%
product_category_df.sample(3)
# Out:
#           sku                                              name  \
# 4261  STM0094  Dux STM Case Macbook Air 13 "Black / Transparent
# 8110  LOG0237     Logitech Harmony Remote Intelligent Companion
# 6486  SNN0022       Sonnet Echo Express SE Thunderbolt PCIe box
#
#                                                                                                     desc  \
# 4261                                                     Transparent protective cover for MacBook Air 13
# 8110  Intelligent controller with direct control button and compatible numeric keys with 270.000 devices
# 6486                                                            Thunderbolt Expansion Chassis PCIe Cards
#
#        price  in_stock      type
# 4261   59.95         1  13835403
# 8110  129.00         1  11905404
# 6486  482.79         0  12995397

# %% [markdown]
# Categories will emerge from the ``products`` table, specifically from the ``name`` and the ``desc`` columns. Therefore, we will explore them and come up with general rules about patterns (words, characters, sequences…) that can reliably tell that a certain product belongs to one of the categories we want to have.

# %% [markdown]
# We set a high number for pandas ``max_rows`` to be able to scroll through the DataFrame and be able to read the full product name and description, and check whether or not the rules we created make sense.

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option("display.max_colwidth", 100)

# %% [markdown]
# ## 1.&nbsp; Category creation by search term
# Let's start by creating a column `category`. For now we'll fill this column with a blank string `""`.

# %%
product_category_df["category"] = ""
product_category_df.sample(2)
# Out:
#           sku                                              name  \
# 1120  PAC0593  Apple Mac mini Core i5 14GHz | 4GB RAM | 1TB SSD
# 8445  NKI0014             Nokia Body Cardio Balance Scale White
#
#                                                                         desc  \
# 1120                    PC Mac mini Core i5 14GHz 4GB 1TB SSD (MGEM2YP / A).
# 8445  scale measuring cardiovascular health and body APP for iPad and iPhone
#
#         price  in_stock      type category
# 1120  1275.59         0      1282
# 8445   179.99         1  11905404

# %% [markdown]
# We can find all the products with certain words in their `description` using `.loc[]` and `.str.contains()`. Here we'll look at all the items that have the word `keyboard` in their description.

# %%
product_category_df.loc[product_category_df["desc"].str.contains("keyboard", case=False)].sample(2)
# Out:
#             sku                                                 name  \
# 6994    LOG0229  Logitech Desktop MK120 Keyboard and USB Mouse Black
# 9625  MAT0004-A              Open - Matias Aluminum Keyboard Spanish
#
#                                                            desc  price  \
# 6994      Keyboard and mouse with USB connection for Mac and PC  25.99
# 9625  Reconditioned keyboard cable compatible with Mac features  69.99
#
#       in_stock      type category
# 6994         1  13855401
# 9625         0  13855401

# %% [markdown]
# Next, we change the value in the category column to `keyboard` for all of these keyboard products.

# %%
product_category_df.loc[product_category_df["desc"].str.contains("keyboard", case=False), "category"] = "keyboard"

# %% [markdown]
# Let's take a look at the effect that had on the `category` column.

# %%
product_category_df["category"].value_counts()
# Out:
# category
#             9903
# keyboard      89
# Name: count, dtype: int64

# %% [markdown]
# ## 2.&nbsp; Category creation using regex
# We can also use a product's `name` to select products for our categories.

# %%
product_category_df.loc[product_category_df["name"].str.contains("apple iphone", case=False)].sample(2)
# Out:
#           sku                                         name  \
# 2058  APP1014            Lightning White Apple iPhone Dock
# 6880  APP2032  Open - Apple iPhone 6s 64GB Gold - like new
#
#                                                           desc  price  \
# 2058  Stand with Lightning Dock Connector and iPhone in White.   45.0
# 6880             Apple Apple iPhone 6s 64GB Gold (MKQP2QL / A)  769.0
#
#       in_stock      type category
# 2058         0  13615399
# 6880         0      1716

# %% [markdown]
# Let's look for names, which starts with ``apple iphone``:

# %%
product_category_df.loc[product_category_df["name"].str.contains("^apple iphone", case=False)].sample(2)
# Out:
#           sku                                                    name  \
# 8386  APP2529  Apple iPhone Leather Case Cover Skin 8/7 (PRODUCT) RED
# 7519  APP2099         Apple iPhone Leather Case Cover 7 Pink Geranium
#
#                                                               desc  price  \
# 8386  ultrathin leather case and microfiber premium for iPhone 8/7   55.0
# 7519    ultrathin leather case and microfiber premium for iPhone 7   55.0
#
#       in_stock      type category
# 8386         1  11865403
# 7519         0  11865403

# %% [markdown]
# Looks like we get a lot of accessories included in this search. We can refine this using a little regex. Here, we will add `.{0,7}` at the beginning of the search: this means we will find all `apple iphone`s that have 7 or less characters preceding the term "apple iphone" - if there's 8 characters preceding the search term, it won't be found. This should help refine our search by using the nomenclature of the DataFrame to our advantage.
#
# If you feel unsure about regex, you can use [regex101](https://regex101.com/). It's really useful for checking your code, and parts of other people's code that you're unsure about.

# %%
product_category_df.loc[product_category_df["name"].str.contains("^.{0,7}apple iphone", case=False)].sample(2)
# Out:
#           sku                                                  name  \
# 8389  APP2532  Apple iPhone Leather Case Cover Skin 8/7 Blue Cosmos
# 2547  APP1137       Case Apple iPhone 6 / 6S Gray Pink Leather Case
#
#                                                                   desc  price  \
# 8389      ultrathin leather case and microfiber premium for iPhone 8/7   55.0
# 2547  ultrathin leather case and microfiber premium for iPhone 6 / 6S.   55.0
#
#       in_stock      type category
# 8389         1  11865403
# 2547         0  11865403

# %% [markdown]
# We can use the same trick as before to set the category - selecting the `category` column and setting it to the string of our choice. However, ``^.{0,7}apple iphone`` is still not an accurate definition to be used for apple iphones categories.

# %% [markdown]
# ## 3.&nbsp; One product with multiple categories
# A product may fit into multiple categories. To help us create multiple categories for one product, we will use the python addition assignment `+=`. The addition assignment is a shorthand way to add something (number, string, etc...) to a variable without changing the variable name.

# %% [markdown]
# Now let's look at how this can help us in our category creation.
#
# First, we'll reset all the values in the category column to an empty string `""`.

# %%
product_category_df["category"] = ""

# %%
product_category_df.sample(2)
# Out:
#           sku  \
# 1410  KEN0208
# 715   NTE0115
#
#                                                                                name  \
# 1410                                     Kensington UH4000C Hub 4 port power supply
# 715   NewerTech Maxpower 2-port USB / eSATA 6Gb / s PCIe Mac Pro OS X 10.6 - 10.8.2
#
#                                                                    desc  \
# 1410                                    Mac and PC Hub 4 USB 3.0 ports.
# 715   NewerTech eSATA PCIe adapter card for Mac Pro and USB3 2006-2012.
#
#        price  in_stock      type category
# 1410   44.99         0  12995397
# 715   181.99         0      1276

# %% [markdown]
# Now, let's create some categories and utilise the addition assignment.

# %%
product_category_df.loc[product_category_df["desc"].str.contains("keyboard", case=False), "category"] += ", keyboard"
product_category_df.loc[product_category_df["name"].str.contains("^.{0,3}apple iphone", case=False), "category"] += ", smartphone"
product_category_df.loc[product_category_df["name"].str.contains("^.{0,3}apple ipod", case=False), "category"] += ", ipod"
product_category_df.loc[product_category_df["name"].str.contains("^.{0,3}apple ipad|tablet", case=False), "category"] += ", tablet"
product_category_df.loc[product_category_df["name"].str.contains("imac|mac mini|mac pro", case=False), "category"] += ", desktop"

# %%
product_category_df.sample(2)
# Out:
#           sku                                   name  \
# 1082  PAC0520  Synology DS115j Pack | WD 4TB Network
# 8215  APP2484        Apple iPhone 8 Plus 64GB Silver
#
#                                                                   desc  \
# 1082  Synology DS115j NAS Server Pack + 4TB WD Network for Mac and PC.
# 8215                                   Apple iPhone 8 Plus 64GB Silver
#
#        price  in_stock       type      category
# 1082  260.99         0   12175397
# 8215  919.00         1  113281716  , smartphone

# %%
product_category_df["category"].value_counts()
# Out:
# category
#                        8467
# , desktop               923
# , tablet                284
# , smartphone            189
# , keyboard               86
# , ipod                   40
# , keyboard, desktop       2
# , keyboard, tablet        1
# Name: count, dtype: int64

# %% [markdown]
# As we can see, some products now have 2 categories instead of just one. At the end, we can use some string methods to tidy up the opening comma and space in the `category` column:

# %%
product_category_df.loc[:, "category"]=product_category_df["category"].str[2:]
product_category_df["category"].value_counts()
# Out:
# category
#                      8467
# desktop               923
# tablet                284
# smartphone            189
# keyboard               86
# ipod                   40
# keyboard, desktop       2
# keyboard, tablet        1
# Name: count, dtype: int64

# %% [markdown]
# We can also define a column to categorize products using their price:

# %%
product_category_df.loc[:, "price_category"] = ["low" if price < 100 else "Medium" if price <= 500 else "High" for price in product_category_df["price"]]

# %%
product_category_df.sample(2)
# Out:
#           sku                                                          name  \
# 678   MOS0115                Moshi SenseCover iPhone Case SE / 5s / 5 Black
# 3931  BOS0034  Bose SoundLink AE II Bluetooth Headset with Microphone Black
#
#                                                                      desc  \
# 678                              Case for iPhone touch sensor SE / 5s / 5
# 3931  HD light with microphone for iPhone iPad and iPod wireless headset.
#
#       price  in_stock      type category price_category
# 678    45.0         0  11865403                     low
# 3931  229.0         0      5384                  Medium

# %% [markdown]
# We can also define a mask to look for strings in both ``name`` and ``description``.

# %%
hard_disk_mask = (
    (product_category_df["name"].str.contains("hard drive|Hard disk", case=False)) 
    | 
    (product_category_df["desc"].str.contains("hard drive|Hard disk", case=False)) 
    & 
    ~(product_category_df["name"].str.contains("adapter", case=False)) 
    | 
    ~(product_category_df["desc"].str.contains("adapter", case=False))
    )

product_category_df.loc[hard_disk_mask, "category"] += ", hard disk drive"

# %%
product_category_df["category"].value_counts()
# Out:
# category
# , hard disk drive                     8150
# desktop, hard disk drive               904
#                                        317
# tablet, hard disk drive                284
# smartphone, hard disk drive            189
# keyboard, hard disk drive               86
# ipod, hard disk drive                   40
# desktop                                 19
# keyboard, desktop, hard disk drive       2
# keyboard, tablet, hard disk drive        1
# Name: count, dtype: int64

# %% [markdown]
# Let's create multiple categories for the most repetitive expressions in ``name`` and ``description`` columns:

# %%
hard_drive_mask = (product_category_df["name"].str.contains("hard drive", case=False)) | (product_category_df["desc"].str.contains("hard drive", case=False))
hard_disk_mask = (product_category_df["name"].str.contains("Hard disk", case=False)) | (product_category_df["desc"].str.contains("Hard disk", case=False))
product_category_df.loc[hard_drive_mask | hard_disk_mask, "category"] += ", hard disk drive"
product_category_df.loc[(product_category_df["name"].str.contains("keyboard", case=False)) | (product_category_df["desc"].str.contains("keyboard", case=False)), "category"] += ", keyboard"
product_category_df.loc[(product_category_df["name"].str.contains("^.{0,7}apple iphone", case=False)) | (product_category_df["desc"].str.contains("apple iphone", case=False)), "category"] += ", smartphone"
product_category_df.loc[(product_category_df["name"].str.contains("apple ipod", case=False)) | (product_category_df["desc"].str.contains("^.{0,7}apple ipod", case=False)), "category"] += ", ipod"
product_category_df.loc[(product_category_df["name"].str.contains("^.{0,7}apple ipad|tablet|ipad", case=False)) | (product_category_df["desc"].str.contains("^.{0,7}apple ipad|tablet|ipad", case=False)), "category"] += ", tablet"
product_category_df.loc[(product_category_df["name"].str.contains("imac|mac mini|mac pro", case=False)) | (product_category_df["desc"].str.contains("imac|mac mini|mac pro", case=False)), "category"] += ", desktop"
product_category_df.loc[(product_category_df["name"].str.contains("software", case=False)) | (product_category_df["desc"].str.contains("software", case=False)), "category"] += ", software"
product_category_df.loc[(product_category_df["name"].str.contains("Battery", case=False)) | (product_category_df["desc"].str.contains("Battery", case=False)), "category"] += ", battery"
product_category_df.loc[(product_category_df["name"].str.contains("Dell", case=False)) | (product_category_df["desc"].str.contains("Dell", case=False)), "category"] += ", Dell"
product_category_df.loc[(product_category_df["name"].str.contains("Display", case=False)) | (product_category_df["desc"].str.contains("Display", case=False)), "category"] += ", display"
product_category_df.loc[(product_category_df["name"].str.contains("Monitor", case=False)) | (product_category_df["desc"].str.contains("Monitor", case=False)), "category"] += ", monitor"
product_category_df.loc[(product_category_df["name"].str.contains("bulb", case=False)) | (product_category_df["desc"].str.contains("bulb", case=False)), "category"] += ", Light bulb"
product_category_df.loc[(product_category_df["name"].str.contains("Case|cover", case=False)) | (product_category_df["desc"].str.contains("Case|cover", case=False)), "category"] += ", Case"
product_category_df.loc[(product_category_df["name"].str.contains("Bose", case=False)) | (product_category_df["desc"].str.contains("Bose", case=False)), "category"] += ", Bose"
product_category_df.loc[(product_category_df["name"].str.contains("Headphones", case=False)) | (product_category_df["desc"].str.contains("Headphones", case=False)) | (product_category_df["name"].str.contains("headset", case=False)) | (product_category_df["desc"].str.contains("headset", case=False)), "category"] += ", headphone"
product_category_df.loc[(product_category_df["name"].str.contains("RAM | Memory Card", case=False)) | (product_category_df["desc"].str.contains("RAM | Memory Card", case=False)), "category"] += ", RAM"
product_category_df.loc[(product_category_df["name"].str.contains("strip", case=False)) | (product_category_df["desc"].str.contains("strip", case=False)), "category"] += ", plug strip"
product_category_df.loc[(product_category_df["name"].str.contains("Seagate", case=False)) | (product_category_df["desc"].str.contains("Seagate", case=False)), "category"] += ", Seagate hard disk drive"
product_category_df.loc[(product_category_df["name"].str.contains("USB", case=False)) | (product_category_df["desc"].str.contains("USB", case=False)), "category"] += ", USB"
product_category_df.loc[(product_category_df["name"].str.contains("adapter", case=False)) | (product_category_df["desc"].str.contains("adapter", case=False)), "category"] += ", adapter"
product_category_df.loc[(product_category_df["name"].str.contains("Nas", case=False)) | (product_category_df["desc"].str.contains("Nas", case=False)), "category"] += ", Nas (network-attached storage)"
product_category_df.loc[(product_category_df["name"].str.contains("Replacement|piece|pieces", case=False)) | (product_category_df["desc"].str.contains("Replacement|piece|pieces", case=False)), "category"] += ", pieces"
product_category_df.loc[(product_category_df["name"].str.contains("Glass|screen protector", case=False)) | (product_category_df["desc"].str.contains("Glass|screen protector", case=False)), "category"] += ", glass or screen protector"
product_category_df.loc[(product_category_df["name"].str.contains("Backpack", case=False)) | (product_category_df["desc"].str.contains("Backpack", case=False)), "category"] += ", Backpack"
product_category_df.loc[(product_category_df["name"].str.contains("Cable", case=False)) | (product_category_df["desc"].str.contains("Cable", case=False)), "category"] += ", Cable"
product_category_df.loc[(product_category_df["name"].str.contains("player", case=False)) | (product_category_df["desc"].str.contains("player", case=False)), "category"] += ", music player"
product_category_df.loc[(product_category_df["name"].str.contains("Repair", case=False)) | (product_category_df["desc"].str.contains("Repair", case=False)), "category"] += ", repair"
product_category_df.loc[(product_category_df["name"].str.contains("gloves", case=False)) | (product_category_df["desc"].str.contains("gloves", case=False)), "category"] += ", gloves"
product_category_df.loc[(product_category_df["name"].str.contains("expansion", case=False)) | (product_category_df["desc"].str.contains("expansion", case=False)), "category"] += ", expansion"
product_category_df.loc[(product_category_df["name"].str.contains("holder", case=False)) | (product_category_df["desc"].str.contains("holder", case=False)), "category"] += ", holder"
product_category_df.loc[(product_category_df["name"].str.contains("Synology", case=False)) | (product_category_df["desc"].str.contains("Synology", case=False)), "category"] += ", cloud storage"
product_category_df.loc[(product_category_df["name"].str.contains("Beats", case=False)) | (product_category_df["desc"].str.contains("Beats", case=False)), "category"] += ", Beats"
product_category_df.loc[(product_category_df["name"].str.contains("support|Bracelet|cuff", case=False)) | (product_category_df["desc"].str.contains("support|Bracelet|cuff", case=False)), "category"] += ", accessories"
product_category_df.loc[(product_category_df["name"].str.contains("Apple Watch", case=False)) | (product_category_df["desc"].str.contains("Apple Watch", case=False)), "category"] += ", Apple Watch"
product_category_df.loc[(product_category_df["name"].str.contains("charger", case=False)) | (product_category_df["desc"].str.contains("charger", case=False)), "category"] += ", charger"
product_category_df.loc[(product_category_df["name"].str.contains("storage|SSD", case=False)) | (product_category_df["desc"].str.contains("storage|SSD", case=False)), "category"] += ", storage"
product_category_df.loc[(product_category_df["name"].str.contains("Refurbished|Open|Like new", case=False)) | (product_category_df["desc"].str.contains("Refurbished|Open|Like new", case=False)), "category"] += ", second-hand/refurbished"
product_category_df.loc[(product_category_df["name"].str.contains("Moleskine", case=False)) | (product_category_df["desc"].str.contains("Moleskine", case=False)), "category"] += ", Moleskine produces"
product_category_df.loc[(product_category_df["name"].str.contains("Router", case=False)) | (product_category_df["desc"].str.contains("Router", case=False)), "category"] += ", router"
product_category_df.loc[(product_category_df["name"].str.contains("handsfree", case=False)) | (product_category_df["desc"].str.contains("handsfree", case=False)), "category"] += ", handsfree"
product_category_df.loc[(product_category_df["name"].str.contains("sensor", case=False)) | (product_category_df["desc"].str.contains("sensor", case=False)), "category"] += ", sensor"
product_category_df.loc[(product_category_df["name"].str.contains("Sleeve", case=False)) | (product_category_df["desc"].str.contains("Sleeve", case=False)), "category"] += ", Laptop Cases"
product_category_df.loc[(product_category_df["name"].str.contains("locator", case=False)) | (product_category_df["desc"].str.contains("locator", case=False)), "category"] += ", Bluetooth locator"
product_category_df.loc[(product_category_df["name"].str.contains("Trackpad", case=False)) | (product_category_df["desc"].str.contains("Trackpad", case=False)), "category"] += ", Trackpad"
product_category_df.loc[(product_category_df["name"].str.contains("Spray", case=False)) | (product_category_df["desc"].str.contains("Spray", case=False)), "category"] += ", cleaners"
product_category_df.loc[(product_category_df["name"].str.contains("Smartwatch", case=False)) | (product_category_df["desc"].str.contains("Smartwatch", case=False)), "category"] += ", Smartwatch"
product_category_df.loc[(product_category_df["name"].str.contains("Fitbit", case=False)) | (product_category_df["desc"].str.contains("Fitbit", case=False)), "category"] += ", Fitbit"
product_category_df.loc[(product_category_df["name"].str.contains("hardware|Mouse", case=False)) | (product_category_df["desc"].str.contains("hardware|Mouse", case=False)), "category"] += ", hardware"
product_category_df.loc[(product_category_df["name"].str.contains("Care|warranty", case=False)) | (product_category_df["desc"].str.contains("Care|warranty", case=False)), "category"] += ", Care|warranty"
product_category_df.loc[(product_category_df["name"].str.contains("service", case=False)) | (product_category_df["desc"].str.contains("service", case=False)), "category"] += ", service"
product_category_df.loc[(product_category_df["name"].str.contains("tools|Screwdriver", case=False)) | (product_category_df["desc"].str.contains("tools|Screwdriver", case=False)), "category"] += ", tools"
product_category_df.loc[(product_category_df["name"].str.contains("Camera", case=False)) | (product_category_df["desc"].str.contains("Camera", case=False)), "category"] += ", Camera"
product_category_df.loc[(product_category_df["name"].str.contains("games|game", case=False)) | (product_category_df["desc"].str.contains("games|game", case=False)), "category"] += ", games"
product_category_df.loc[(product_category_df["name"].str.contains("robot|Robotic", case=False)) | (product_category_df["desc"].str.contains("robot|Robotic", case=False)), "category"] += ", robot"

# %%
product_category_df["category"].value_counts()
# Out:
# category
# , hard disk drive, Case                                                                                                 893
# , hard disk drive                                                                                                       311
# desktop, hard disk drive, desktop, RAM                                                                                  290
# , hard disk drive, tablet                                                                                               265
# , hard disk drive, RAM, storage                                                                                         236
# , hard disk drive, USB                                                                                                  203
# desktop, hard disk drive, desktop, RAM, storage                                                                         202
# , hard disk drive, hard disk drive, USB                                                                                 187
# , hard disk drive, desktop, RAM                                                                                         175
# , hard disk drive, tablet, Case                                                                                         159
# , hard disk drive, Case, second-hand/refurbished                                                                        153
# tablet, hard disk drive, tablet                                                                                         151
# , hard disk drive, Apple Watch                                                                                          145
# , hard disk drive, RAM                                                                                                  137
# , hard disk drive, smartphone, second-hand/refurbished                                                                  132
# , hard disk drive, RAM, Seagate hard disk drive, Nas (network-attached storage), cloud storage                          116
# , hard disk drive, Nas (network-attached storage), cloud storage                                                        109
# , hard disk drive, tablet, second-hand/refurbished                                                                      106
# smartphone, hard disk drive, smartphone                                                                                 104
# , hard disk drive, RAM, Nas (network-attached storage), cloud storage                                                    87
# , hard disk drive, Case, Laptop Cases                                                                                    86
# desktop, hard disk drive, desktop, storage                                                                               86
# , hard disk drive, accessories                                                                                           85
# smartphone, hard disk drive, smartphone, Case                                                                            84
# , USB, adapter                                                                                                           80
# , hard disk drive, glass or screen protector                                                                             79
# , hard disk drive, second-hand/refurbished                                                                               76
# , hard disk drive, monitor                                                                                               75
# tablet, hard disk drive, tablet, Case                                                                                    75
# , hard disk drive, RAM, Nas (network-attached storage)                                                                   74
# , hard disk drive, hard disk drive                                                                                       72
# , hard disk drive, storage                                                                                               71
# , hard disk drive, USB, Cable                                                                                            68
# , hard disk drive, Cable                                                                                                 64
# , hard disk drive, hard disk drive, storage                                                                              61
# , hard disk drive, hard disk drive, USB, second-hand/refurbished                                                         58
# desktop, hard disk drive, desktop, expansion, storage, tools                                                             57
# desktop, hard disk drive, desktop, RAM, second-hand/refurbished                                                          57
# , hard disk drive, Seagate hard disk drive, Nas (network-attached storage), cloud storage                                53
# , adapter                                                                                                                53
# , hard disk drive, battery                                                                                               51
# , hard disk drive, Case, Apple Watch                                                                                     51
# , hard disk drive, repair, service                                                                                       49
# , hard disk drive, pieces                                                                                                49
# , hard disk drive, RAM, second-hand/refurbished                                                                          46
# , hard disk drive, tablet, accessories                                                                                   45
# , hard disk drive, tablet, headphone                                                                                     45
# , hard disk drive, USB, second-hand/refurbished                                                                          44
# , hard disk drive, Nas (network-attached storage)                                                                        44
# , hard disk drive, tablet, USB, Cable                                                                                    43
# , hard disk drive, tablet, Case, second-hand/refurbished                                                                 43
# , hard disk drive, RAM, Seagate hard disk drive, Nas (network-attached storage)                                          43
# , hard disk drive, display, RAM, storage                                                                                 42
# , hard disk drive, battery, Case                                                                                         42
# , hard disk drive, hard disk drive, Nas (network-attached storage)                                                       42
# , hard disk drive, display, RAM                                                                                          41
# , hard disk drive, RAM, storage, second-hand/refurbished                                                                 39
# , hard disk drive, tablet, repair, service                                                                               39
# , hard disk drive, expansion, storage, tools                                                                             39
# , hard disk drive, tablet, USB                                                                                           39
# , hard disk drive, tablet, Case, accessories                                                                             38
# , hard disk drive, hard disk drive, Seagate hard disk drive, Nas (network-attached storage), cloud storage               37
# , hard disk drive, monitor, second-hand/refurbished                                                                      34
# , hard disk drive, Dell, monitor                                                                                         33
# , hard disk drive, hard disk drive, Seagate hard disk drive, Nas (network-attached storage)                              32
# , hard disk drive, desktop                                                                                               32
# , hard disk drive, tablet, Case, Laptop Cases                                                                            30
# , hard disk drive, tablet, battery                                                                                       30
# , hard disk drive, tablet, headphone, Beats                                                                              29
# , hard disk drive, Case, holder, accessories                                                                             28
# , hard disk drive, Backpack                                                                                              28
# , hard disk drive, cloud storage                                                                                         27
# , hard disk drive, hard disk drive, RAM, Seagate hard disk drive, Nas (network-attached storage)                         27
# , hard disk drive, tablet, Camera                                                                                        27
# , hard disk drive, smartphone, Case                                                                                      27
# , hard disk drive, USB, storage                                                                                          27
# , hard disk drive, hard disk drive, RAM, Nas (network-attached storage)                                                  26
# , hard disk drive, Case, accessories                                                                                     26
# , hard disk drive, display, Case, Apple Watch                                                                            26
# , hard disk drive, hard disk drive, Seagate hard disk drive                                                              25
# , hard disk drive, hard disk drive, Seagate hard disk drive, USB                                                         25
# , hard disk drive, charger                                                                                               24
# , hard disk drive, expansion                                                                                             24
# , hard disk drive, hard disk drive, RAM                                                                                  23
# , hard disk drive, Case, glass or screen protector                                                                       22
# desktop, hard disk drive, desktop, RAM, expansion, storage, tools                                                        22
# , hard disk drive, hard disk drive, USB, storage                                                                         22
# , hard disk drive, Case, Apple Watch, second-hand/refurbished                                                            22
# desktop, hard disk drive, desktop, display, RAM                                                                          21
# , hard disk drive, router                                                                                                20
# , hard disk drive, tablet, monitor                                                                                       20
# , hard disk drive, tablet, battery, USB                                                                                  20
# , hard disk drive, hard disk drive, second-hand/refurbished                                                              20
# desktop, hard disk drive, desktop, RAM, Trackpad                                                                         20
# tablet, hard disk drive, tablet, Case, Laptop Cases                                                                      19
# , hard disk drive, hard disk drive, RAM, Seagate hard disk drive                                                         19
# , hard disk drive, RAM, expansion, storage                                                                               19
# , hard disk drive, Camera                                                                                                19
# , hard disk drive, Apple Watch, second-hand/refurbished                                                                  19
# , hard disk drive, tablet, glass or screen protector                                                                     18
# , hard disk drive, tablet, Bose, headphone                                                                               18
# , hard disk drive, Seagate hard disk drive                                                                               18
# , hard disk drive, monitor, Case, Apple Watch                                                                            18
# , adapter, second-hand/refurbished                                                                                       17
# , USB, adapter, second-hand/refurbished                                                                                  17
# , hard disk drive, headphone                                                                                             17
# , hard disk drive, Light bulb                                                                                            17
# desktop, hard disk drive, desktop, expansion, storage                                                                    17
# ipod, hard disk drive, ipod, Camera                                                                                      16
# , hard disk drive, hard disk drive, Seagate hard disk drive, cloud storage                                               16
# , hard disk drive, hard disk drive, storage, second-hand/refurbished                                                     16
# , RAM, adapter                                                                                                           16
# , hard disk drive, hardware                                                                                              16
# keyboard, hard disk drive, keyboard, tablet, Case                                                                        16
# ipod, hard disk drive, ipod, music player                                                                                16
# , hard disk drive, hard disk drive, cloud storage                                                                        16
# , hard disk drive, hard disk drive, RAM, cloud storage                                                                   16
# , hard disk drive, Cable, accessories                                                                                    16
# , hard disk drive, tablet, tools                                                                                         15
# , hard disk drive, Seagate hard disk drive, Nas (network-attached storage)                                               15
# , hard disk drive, Cable, second-hand/refurbished                                                                        15
# , hard disk drive, desktop, RAM, second-hand/refurbished                                                                 15
# , hard disk drive, storage, second-hand/refurbished                                                                      15
# , hard disk drive, Dell, monitor, second-hand/refurbished                                                                14
# , hard disk drive, RAM, Seagate hard disk drive, Nas (network-attached storage), cloud storage, storage                  14
# , hard disk drive, Case, Backpack                                                                                        14
# , hard disk drive, tablet, USB, charger                                                                                  14
# , hard disk drive, RAM, expansion, storage, tools                                                                        14
# , display, adapter                                                                                                       14
# , hard disk drive, battery, USB                                                                                          14
# , hard disk drive, Laptop Cases                                                                                          14
# , hard disk drive, accessories, second-hand/refurbished                                                                  14
# , hard disk drive, expansion, storage                                                                                    14
# , hard disk drive, sensor                                                                                                14
# , hard disk drive, Case, holder                                                                                          13
# desktop, hard disk drive, desktop, RAM, Trackpad, hardware                                                               13
# , hard disk drive, holder, accessories                                                                                   13
# , hard disk drive, USB, charger                                                                                          13
# , hard disk drive, hard disk drive, storage, second-hand/refurbished, tools                                              13
# keyboard, hard disk drive, keyboard, tablet                                                                              13
# , hard disk drive, tablet, Bose                                                                                          13
# , hard disk drive, hard disk drive, Seagate hard disk drive, second-hand/refurbished                                     12
# , hard disk drive, software                                                                                              12
# , hard disk drive, robot                                                                                                 12
# , hard disk drive, RAM, cloud storage                                                                                    12
# , hard disk drive, Nas (network-attached storage), expansion, cloud storage                                              12
# , hard disk drive, hard disk drive, RAM, Seagate hard disk drive, cloud storage                                          12
# , hard disk drive, RAM, Nas (network-attached storage), cloud storage, storage                                           12
# , USB, adapter, Cable                                                                                                    12
# , hard disk drive, hard disk drive, USB, Care|warranty                                                                   12
# tablet, hard disk drive, tablet, software                                                                                12
# , hard disk drive, display, monitor                                                                                      12
# , hard disk drive, Case, pieces, Laptop Cases                                                                            11
# , hard disk drive, battery, second-hand/refurbished                                                                      11
# , hard disk drive, tablet, robot                                                                                         11
# , hard disk drive, USB, Cable, second-hand/refurbished                                                                   11
# desktop, hard disk drive, desktop, accessories                                                                           11
# tablet, hard disk drive, tablet, second-hand/refurbished                                                                 11
# , hard disk drive, expansion, storage, second-hand/refurbished, tools                                                    11
# , hard disk drive, tablet, USB, Cable, second-hand/refurbished                                                           11
# , hard disk drive, hard disk drive, Nas (network-attached storage), cloud storage                                        11
# , hard disk drive, tablet, sensor                                                                                        11
# , hard disk drive, hard disk drive, Nas (network-attached storage), second-hand/refurbished                              11
# , hard disk drive, charger, second-hand/refurbished                                                                      10
# , hard disk drive, Care|warranty                                                                                         10
# , hard disk drive, tablet, Backpack                                                                                      10
# , hard disk drive, tablet, Light bulb                                                                                    10
# , hard disk drive, ipod, music player, second-hand/refurbished                                                           10
# , hard disk drive, accessories, Apple Watch                                                                              10
# , hard disk drive, tools                                                                                                 10
# , hard disk drive, battery, pieces                                                                                       10
# , hard disk drive, battery, pieces, tools                                                                                10
# , hard disk drive, tablet, USB, second-hand/refurbished                                                                  10
# , hard disk drive, RAM, USB, Nas (network-attached storage)                                                              10
# keyboard, hard disk drive, keyboard, tablet, Case, second-hand/refurbished                                               10
# desktop, hard disk drive, desktop                                                                                        10
# , hard disk drive, tablet, Cable                                                                                         10
# , hard disk drive, battery, repair, service                                                                              10
# , hard disk drive, Case, pieces                                                                                          10
# , hard disk drive, monitor, USB                                                                                           9
# , hard disk drive, accessories, Camera                                                                                    9
# , hard disk drive, Bluetooth locator                                                                                      9
# , hard disk drive, tablet, charger                                                                                        9
# , hard disk drive, Case, glass or screen protector, Apple Watch                                                           9
# desktop, hard disk drive, desktop, storage, tools                                                                         8
# , smartphone, battery, adapter, pieces                                                                                    8
# , hard disk drive, tablet, Case, second-hand/refurbished, Laptop Cases                                                    8
# , hard disk drive, Nas (network-attached storage), second-hand/refurbished                                                8
# , hard disk drive, glass or screen protector, second-hand/refurbished                                                     8
# , hard disk drive, plug strip                                                                                             8
# ipod, hard disk drive, ipod                                                                                               8
# , hard disk drive, Bose                                                                                                   8
# , hard disk drive, hard disk drive, RAM, Seagate hard disk drive, Nas (network-attached storage), cloud storage           8
# , hard disk drive, hard disk drive, Seagate hard disk drive, Nas (network-attached storage), second-hand/refurbished      8
# , hard disk drive, Nas (network-attached storage), cloud storage, second-hand/refurbished                                 8
# , hard disk drive, battery, Case, second-hand/refurbished                                                                 8
# , hard disk drive, Case, second-hand/refurbished, Laptop Cases                                                            7
# , hard disk drive, Case, accessories, second-hand/refurbished                                                             7
# , hard disk drive, headphone, Cable, Beats                                                                                7
# , hard disk drive, monitor, accessories, Fitbit                                                                           7
# desktop, desktop, adapter, expansion, storage                                                                             7
# , hard disk drive, Nas (network-attached storage), expansion                                                              7
# , display, USB, adapter                                                                                                   7
# , hard disk drive, Case, holder, accessories, handsfree                                                                   7
# , hard disk drive, display, Cable                                                                                         7
# , hard disk drive, tablet, battery, Bose                                                                                  7
# , hard disk drive, desktop, expansion, storage, tools                                                                     7
# , hard disk drive, display, Case, accessories, Apple Watch                                                                7
# , hard disk drive, plug strip, USB                                                                                        7
# , hard disk drive, music player                                                                                           7
# , hard disk drive, battery, USB, Cable                                                                                    7
# , hard disk drive, tablet, gloves                                                                                         7
# , hard disk drive, tablet, Case, accessories, second-hand/refurbished                                                     7
# keyboard, hard disk drive, keyboard, tablet, second-hand/refurbished                                                      7
# , hard disk drive, Case, glass or screen protector, accessories                                                           7
# , hard disk drive, Smartwatch                                                                                             7
# , hard disk drive, adapter                                                                                                6
# , hard disk drive, display, RAM, second-hand/refurbished                                                                  6
# , hard disk drive, Nas (network-attached storage), cloud storage, storage                                                 6
# , hard disk drive, desktop, storage                                                                                       6
# , hard disk drive, tablet, Case, repair, service                                                                          6
# , hard disk drive, repair, service, Camera                                                                                6
# , hard disk drive, RAM, Nas (network-attached storage), second-hand/refurbished                                           6
# , hard disk drive, headphone, repair, service                                                                             6
# , hard disk drive, Case, USB                                                                                              6
# , hard disk drive, RAM, Nas (network-attached storage), tools                                                             6
# , hard disk drive, smartphone, Case, second-hand/refurbished                                                              6
# , hard disk drive, tablet, battery, headphone                                                                             6
# , hard disk drive, tablet, headphone, Apple Watch                                                                         6
# , hard disk drive, smartphone, tablet, battery, headphone, Beats                                                          6
# , hard disk drive, tablet, battery, headphone, Beats, Apple Watch                                                         6
# , tablet, adapter                                                                                                         6
# , display, adapter, Cable                                                                                                 6
# , hard disk drive, display                                                                                                6
# desktop, hard disk drive, desktop, RAM, storage, second-hand/refurbished                                                  6
# , hard disk drive, RAM, Seagate hard disk drive, cloud storage                                                            6
# desktop, hard disk drive, desktop, storage, second-hand/refurbished                                                       6
# , hard disk drive, smartphone                                                                                             6
# , hard disk drive, hard disk drive, Seagate hard disk drive, USB, expansion                                               6
# , hard disk drive, tablet, handsfree                                                                                      6
# , hard disk drive, hard disk drive, Care|warranty                                                                         6
# , hard disk drive, RAM, adapter                                                                                           6
# , hard disk drive, tablet, battery, USB, Cable                                                                            6
# , hard disk drive, Case, second-hand/refurbished, sensor                                                                  6
# , hard disk drive, tablet, headphone, second-hand/refurbished                                                             6
# , hard disk drive, display, monitor, second-hand/refurbished                                                              6
# , hard disk drive, pieces, sensor, Camera                                                                                 6
# , hard disk drive, tablet, plug strip                                                                                     5
# , hard disk drive, monitor, accessories                                                                                   5
# , hard disk drive, tablet, battery, Camera                                                                                5
# , adapter, storage                                                                                                        5
# , hard disk drive, ipod, second-hand/refurbished, Camera                                                                  5
# , hard disk drive, display, pieces, tools                                                                                 5
# , hard disk drive, music player, second-hand/refurbished                                                                  5
# , hard disk drive, monitor, USB, second-hand/refurbished                                                                  5
# desktop, hard disk drive, desktop, Cable                                                                                  5
# , hard disk drive, Dell, monitor, USB                                                                                     5
# , hard disk drive, tablet, monitor, accessories                                                                           5
# , hard disk drive, tablet, storage                                                                                        5
# , hard disk drive, glass or screen protector, Apple Watch                                                                 5
# , hard disk drive, Case, USB, storage, second-hand/refurbished                                                            5
# , hard disk drive, tablet, Cable, charger                                                                                 5
# , hard disk drive, tablet, software                                                                                       5
# , hard disk drive, Case, glass or screen protector, Laptop Cases                                                          5
# , hard disk drive, tablet, RAM, Nas (network-attached storage), cloud storage                                             5
# , hard disk drive, hard disk drive, tablet, Nas (network-attached storage), cloud storage                                 5
# , hard disk drive, headphone, accessories                                                                                 5
# , hard disk drive, hard disk drive, Case, USB                                                                             5
# , hard disk drive, tablet, battery, second-hand/refurbished                                                               5
# keyboard, hard disk drive, keyboard                                                                                       5
# , hard disk drive, second-hand/refurbished, Smartwatch                                                                    5
# , hard disk drive, tablet, monitor, second-hand/refurbished                                                               5
# , hard disk drive, hard disk drive, Cable                                                                                 5
# , hard disk drive, Case, USB, storage                                                                                     5
# , hard disk drive, expansion, second-hand/refurbished                                                                     5
# , hard disk drive, Light bulb, second-hand/refurbished                                                                    5
# , display, adapter, second-hand/refurbished                                                                               5
# , hard disk drive, tablet, games                                                                                          5
# , hard disk drive, tablet, USB, Cable, charger                                                                            4
# , hard disk drive, USB, accessories                                                                                       4
# keyboard, hard disk drive, keyboard, Trackpad                                                                             4
# , hard disk drive, Cable, Apple Watch                                                                                     4
# , display, USB, adapter, Cable                                                                                            4
# desktop, hard disk drive, desktop, RAM, expansion, storage                                                                4
# , hard disk drive, monitor, Camera                                                                                        4
# , hard disk drive, monitor, Care|warranty                                                                                 4
# , hard disk drive, second-hand/refurbished, hardware                                                                      4
# , hard disk drive, accessories, Apple Watch, Laptop Cases                                                                 4
# , hard disk drive, pieces, Cable                                                                                          4
# , hard disk drive, tablet, Case, Backpack                                                                                 4
# , hard disk drive, tablet, Bose, headphone, glass or screen protector                                                     4
# , hard disk drive, tablet, USB, storage                                                                                   4
# , hard disk drive, tablet, Beats                                                                                          4
# , hard disk drive, Seagate hard disk drive, cloud storage                                                                 4
# , hard disk drive, tablet, Smartwatch                                                                                     4
# , hard disk drive, Case, RAM                                                                                              4
# , hard disk drive, USB, Nas (network-attached storage)                                                                    4
# keyboard, hard disk drive, keyboard, Case                                                                                 4
# , hard disk drive, hard disk drive, RAM, Nas (network-attached storage), cloud storage                                    4
# , hard disk drive, display, Cable, second-hand/refurbished                                                                4
# , hard disk drive, tablet, Laptop Cases                                                                                   4
# tablet, hard disk drive, tablet, Case, accessories                                                                        4
# , hard disk drive, holder                                                                                                 4
# , hard disk drive, monitor, Smartwatch                                                                                    4
# , hard disk drive, accessories, Fitbit                                                                                    4
# , hard disk drive, tablet, accessories, second-hand/refurbished                                                           4
# , hard disk drive, tablet, Apple Watch, Bluetooth locator                                                                 4
# , tablet, adapter, Cable                                                                                                  4
# desktop, hard disk drive, desktop, second-hand/refurbished                                                                4
# , hard disk drive, tablet, headphone, handsfree                                                                           4
# , hard disk drive, battery, Apple Watch                                                                                   4
# , hard disk drive, USB, storage, second-hand/refurbished                                                                  4
# , hard disk drive, headphone, Beats                                                                                       4
# , hard disk drive, USB, Cable, accessories                                                                                4
# , hard disk drive, USB, adapter, second-hand/refurbished                                                                  4
# , hard disk drive, Cable, accessories, Apple Watch                                                                        4
# , hard disk drive, pieces, second-hand/refurbished                                                                        4
# , hard disk drive, USB, adapter                                                                                           4
# , hard disk drive, second-hand/refurbished, Bluetooth locator                                                             4
# , hard disk drive, tablet, router                                                                                         4
# , hard disk drive, battery, sensor, Camera                                                                                4
# , hard disk drive, hard disk drive, USB, adapter, Cable                                                                   4
# , hard disk drive, second-hand/refurbished, robot                                                                         4
# , hard disk drive, tablet, repair, service, Camera                                                                        4
# , hard disk drive, smartphone, battery, Case                                                                              4
# , hard disk drive, tablet, Case, glass or screen protector                                                                3
# desktop, hard disk drive, desktop, adapter, storage                                                                       3
# , headphone, adapter                                                                                                      3
# , hard disk drive, desktop, USB, Cable                                                                                    3
# , hard disk drive, Case, router                                                                                           3
# , hard disk drive, hard disk drive, storage, tools                                                                        3
# , hard disk drive, storage, tools                                                                                         3
# , hard disk drive, pieces, Camera                                                                                         3
# , hard disk drive, pieces, tools                                                                                          3
# , hard disk drive, second-hand/refurbished, tools                                                                         3
# , hard disk drive, battery, plug strip, pieces                                                                            3
# desktop, hard disk drive, hard disk drive, desktop, storage                                                               3
# desktop, hard disk drive, desktop, sensor                                                                                 3
# , hard disk drive, hard disk drive, second-hand/refurbished, Care|warranty                                                3
# , hard disk drive, second-hand/refurbished, Trackpad                                                                      3
# desktop, hard disk drive, desktop, Care|warranty                                                                          3
# , hard disk drive, tablet, monitor, Camera                                                                                3
# desktop, hard disk drive, desktop, RAM, expansion                                                                         3
# , hard disk drive, hard disk drive, storage, hardware                                                                     3
# , hard disk drive, storage, hardware                                                                                      3
# , hard disk drive, Case, robot                                                                                            3
# , hard disk drive, Case, glass or screen protector, Apple Watch, second-hand/refurbished                                  3
# , USB, adapter, accessories                                                                                               3
# , hard disk drive, display, USB                                                                                           3
# , hard disk drive, keyboard, tablet                                                                                       3
# , tablet, adapter, second-hand/refurbished                                                                                3
# , hard disk drive, tablet, Apple Watch, sensor                                                                            3
# , hard disk drive, monitor, sensor                                                                                        3
# , hard disk drive, display, Case, Apple Watch, second-hand/refurbished                                                    3
# , hard disk drive, repair                                                                                                 3
# , hard disk drive, tablet, Bluetooth locator                                                                              3
# , hard disk drive, hard disk drive, USB, Cable                                                                            3
# , hard disk drive, USB, hardware                                                                                          3
# keyboard, hard disk drive, keyboard, USB, second-hand/refurbished                                                         3
# , hard disk drive, hard disk drive, desktop, storage                                                                      3
# , hard disk drive, Smartwatch, Fitbit                                                                                     3
# , hard disk drive, cloud storage, Camera                                                                                  3
# , hard disk drive, ipod, Camera                                                                                           3
# , hard disk drive, Dell, monitor, Cable                                                                                   3
# , hard disk drive, adapter, accessories                                                                                   3
# , hard disk drive, tablet, display                                                                                        3
# desktop, hard disk drive, desktop, tools                                                                                  3
# , hard disk drive, second-hand/refurbished, Camera                                                                        3
# , hard disk drive, keyboard, tablet, second-hand/refurbished                                                              3
# , desktop, adapter, expansion, storage                                                                                    3
# , hard disk drive, RAM, Seagate hard disk drive                                                                           3
# , hard disk drive, sensor, Camera                                                                                         3
# , hard disk drive, tablet, glass or screen protector, second-hand/refurbished                                             3
# , hard disk drive, Dell, display, monitor, USB                                                                            3
# , hard disk drive, Case, glass or screen protector, second-hand/refurbished                                               3
# , hard disk drive, RAM, storage, tools                                                                                    3
# , hard disk drive, tablet, headphone, Cable                                                                               3
# , hard disk drive, battery, Cable                                                                                         3
# desktop, hard disk drive, desktop, monitor, accessories                                                                   3
# , hard disk drive, sensor, Care|warranty                                                                                  3
# , hard disk drive, desktop, USB                                                                                           3
# , hard disk drive, hard disk drive, Seagate hard disk drive, storage                                                      3
# desktop, hard disk drive, desktop, RAM, service                                                                           3
# , hard disk drive, RAM, expansion                                                                                         3
# , hard disk drive, storage, service                                                                                       3
# , hard disk drive, Case, holder, accessories, second-hand/refurbished                                                     3
# keyboard, hard disk drive, keyboard, tablet, USB                                                                          3
# ...
# , hard disk drive, hard disk drive, adapter, pieces                                                                       1
# , hard disk drive, tablet, monitor, Smartwatch                                                                            1
# , hard disk drive, Light bulb, expansion, second-hand/refurbished                                                         1
# , hard disk drive, tablet, second-hand/refurbished, Laptop Cases                                                          1
# , hard disk drive, tablet, Backpack, second-hand/refurbished                                                              1
# , hard disk drive, Cable, holder, Apple Watch                                                                             1
# , hard disk drive, second-hand/refurbished, Laptop Cases                                                                  1
# , hard disk drive, second-hand/refurbished, sensor                                                                        1
# , hard disk drive, battery, USB, Cable, Apple Watch, charger                                                              1
# , hard disk drive, display, monitor, USB, accessories                                                                     1
# desktop, hard disk drive, desktop, Case, USB, storage, second-hand/refurbished                                            1
# , hard disk drive, monitor, Case                                                                                          1
# , hard disk drive, tablet, Bose, headphone, second-hand/refurbished                                                       1
# , hard disk drive, software, monitor, accessories                                                                         1
# , smartphone, battery, adapter, pieces, second-hand/refurbished                                                           1
# , hard disk drive, hardware, games                                                                                        1
# , hard disk drive, tablet, adapter, Camera                                                                                1
# , hard disk drive, monitor, headphone                                                                                     1
# , hard disk drive, tablet, Care|warranty                                                                                  1
# , hard disk drive, tablet, battery, headphone, Beats                                                                      1
# , hard disk drive, tablet, Cable, second-hand/refurbished                                                                 1
# keyboard, hard disk drive, keyboard, RAM, storage                                                                         1
# , hard disk drive, tablet, USB, charger, Bluetooth locator                                                                1
# , hard disk drive, hard disk drive, Seagate hard disk drive, USB, Cable                                                   1
# , hard disk drive, second-hand/refurbished, Care|warranty                                                                 1
# , hard disk drive, Case, accessories, Apple Watch, second-hand/refurbished                                                1
# , hard disk drive, RAM, second-hand/refurbished, sensor                                                                   1
# desktop, hard disk drive, desktop, expansion, storage, second-hand/refurbished                                            1
# , hard disk drive, battery, Apple Watch, second-hand/refurbished                                                          1
# , hard disk drive, tablet, RAM, Nas (network-attached storage), cloud storage, second-hand/refurbished                    1
# desktop, hard disk drive, desktop, RAM, second-hand/refurbished, Trackpad                                                 1
# tablet, hard disk drive, tablet, Laptop Cases                                                                             1
# , hard disk drive, second-hand/refurbished, Fitbit                                                                        1
# desktop, hard disk drive, desktop, display, second-hand/refurbished                                                       1
# desktop, hard disk drive, desktop, expansion, storage, second-hand/refurbished, tools                                     1
# , hard disk drive, Case, Cable, second-hand/refurbished                                                                   1
# keyboard, hard disk drive, keyboard, USB, hardware                                                                        1
# , hard disk drive, monitor, hardware                                                                                      1
# desktop, hard disk drive, desktop, second-hand/refurbished, tools                                                         1
# , hard disk drive, adapter, accessories, second-hand/refurbished                                                          1
# , hard disk drive, USB, Nas (network-attached storage), second-hand/refurbished                                           1
# , hard disk drive, Cable, accessories, Apple Watch, second-hand/refurbished                                               1
# , tablet, headphone, adapter, second-hand/refurbished                                                                     1
# , hard disk drive, battery, pieces, second-hand/refurbished                                                               1
# , hard disk drive, tablet, battery, Case, headphone, Beats                                                                1
# , hard disk drive, Light bulb, expansion                                                                                  1
# , ipod, tablet, USB, adapter                                                                                              1
# desktop, hard disk drive, desktop, USB, expansion                                                                         1
# desktop, desktop, adapter, storage, second-hand/refurbished                                                               1
# , tablet, adapter, second-hand/refurbished, Camera                                                                        1
# , hard disk drive, Nas (network-attached storage), cloud storage, Care|warranty                                           1
# , hard disk drive, tablet, second-hand/refurbished, tools                                                                 1
# , hard disk drive, Case, Nas (network-attached storage), second-hand/refurbished                                          1
# , hard disk drive, Cable, Apple Watch, second-hand/refurbished                                                            1
# , hard disk drive, hard disk drive, Seagate hard disk drive, USB, Cable, second-hand/refurbished                          1
# , hard disk drive, tablet, monitor, accessories, sensor                                                                   1
# , hard disk drive, Case, expansion                                                                                        1
# desktop, hard disk drive, hard disk drive, desktop, accessories                                                           1
# , hard disk drive, desktop, Case, USB, storage                                                                            1
# tablet, hard disk drive, tablet, Bose                                                                                     1
# , hard disk drive, Case, Bose                                                                                             1
# , hard disk drive, Case, second-hand/refurbished, robot                                                                   1
# , hard disk drive, display, adapter, second-hand/refurbished                                                              1
# , hard disk drive, display, Case, second-hand/refurbished                                                                 1
# , hard disk drive, adapter, Cable, second-hand/refurbished                                                                1
# , hard disk drive, tablet, battery, USB, second-hand/refurbished                                                          1
# , hard disk drive, Backpack, second-hand/refurbished                                                                      1
# , hard disk drive, USB, charger, second-hand/refurbished                                                                  1
# , hard disk drive, Case, expansion, second-hand/refurbished                                                               1
# , hard disk drive, tablet, holder                                                                                         1
# , hard disk drive, charger, Trackpad                                                                                      1
# keyboard, desktop, hard disk drive, keyboard, desktop, accessories, Trackpad                                              1
# , hard disk drive, tablet, battery, USB, Cable, second-hand/refurbished                                                   1
# , hard disk drive, monitor, Case, accessories, Apple Watch                                                                1
# , adapter, cloud storage, storage                                                                                         1
# , hard disk drive, desktop, display, Cable                                                                                1
# , hard disk drive, Beats                                                                                                  1
# , hard disk drive, Case, Beats                                                                                            1
# , desktop, adapter, Cable                                                                                                 1
# , hard disk drive, tablet, pieces                                                                                         1
# , hard disk drive, Apple Watch, Bluetooth locator                                                                         1
# keyboard, hard disk drive, keyboard, Cable                                                                                1
# , hard disk drive, monitor, Cable                                                                                         1
# , hard disk drive, tablet, Case, headphone, Apple Watch, second-hand/refurbished                                          1
# , tablet, adapter, Cable, second-hand/refurbished                                                                         1
# tablet, hard disk drive, tablet, Moleskine produces                                                                       1
# , hard disk drive, tablet, Moleskine produces                                                                             1
# , hard disk drive, display, monitor, USB, second-hand/refurbished                                                         1
# , hard disk drive, ipod, music player                                                                                     1
# , hard disk drive, Case, USB, second-hand/refurbished                                                                     1
# , hard disk drive, desktop, Case, USB, storage, second-hand/refurbished                                                   1
# keyboard, hard disk drive, keyboard, tablet, Case, accessories, second-hand/refurbished                                   1
# , hard disk drive, smartphone, battery, Case, second-hand/refurbished                                                     1
# desktop, hard disk drive, desktop, glass or screen protector                                                              1
# , hard disk drive, smartphone, tablet, headphone                                                                          1
# , hard disk drive, USB, hardware, games                                                                                   1
# keyboard, desktop, hard disk drive, keyboard, desktop, pieces, service                                                    1
# , display, USB, adapter, Cable, second-hand/refurbished                                                                   1
# , desktop, adapter, storage, second-hand/refurbished                                                                      1
# , hard disk drive, RAM, USB, Nas (network-attached storage), second-hand/refurbished                                      1
# , hard disk drive, second-hand/refurbished, Smartwatch, Fitbit                                                            1
# , hard disk drive, hard disk drive, adapter, pieces, storage                                                              1
# , hard disk drive, accessories, Laptop Cases                                                                              1
# , hard disk drive, charger, hardware                                                                                      1
# , hard disk drive, tablet, second-hand/refurbished, Camera                                                                1
# , hard disk drive, Case, pieces, second-hand/refurbished, Laptop Cases                                                    1
# , hard disk drive, Case, holder, accessories, second-hand/refurbished, Laptop Cases                                       1
# , hard disk drive, battery, second-hand/refurbished, tools                                                                1
# , desktop, USB, adapter                                                                                                   1
# , desktop, adapter                                                                                                        1
# , hard disk drive, plug strip, expansion                                                                                  1
# keyboard, hard disk drive, keyboard, charger, hardware                                                                    1
# , hard disk drive, monitor, second-hand/refurbished, hardware                                                             1
# , hard disk drive, smartphone, accessories, charger, second-hand/refurbished                                              1
# keyboard, hard disk drive, keyboard, Cable, second-hand/refurbished                                                       1
# , hard disk drive, tablet, Case, headphone                                                                                1
# , hard disk drive, tablet, headphone, USB, charger                                                                        1
# , tablet, Light bulb, adapter, Apple Watch                                                                                1
# , hard disk drive, tablet, Case, second-hand/refurbished, Camera                                                          1
# , hard disk drive, tablet, Light bulb, Apple Watch                                                                        1
# , hard disk drive, display, USB, Cable, second-hand/refurbished                                                           1
# , hard disk drive, Backpack, accessories                                                                                  1
# keyboard, hard disk drive, keyboard, cleaners                                                                             1
# , hard disk drive, accessories, charger                                                                                   1
# , hard disk drive, Case, charger                                                                                          1
# keyboard, hard disk drive, keyboard, desktop, pieces, service                                                             1
# , hard disk drive, second-hand/refurbished, games                                                                         1
# , hard disk drive, accessories, second-hand/refurbished, Fitbit                                                           1
# Name: count, dtype: int64

# %%
product_category_df["category"].value_counts().count()
# Out:
# np.int64(776)

# %%
product_category_df.sample(2)
# Out:
#             sku                                             name  \
# 6455  SAN0133-A   Open - SanDisk SSD 480GB Plus 25 "SATA 6Gb / s
# 653     PAR0014  Parrot Flower Power Plants Wireless Sensor Blue
#
#                                             desc   price  in_stock      type  \
# 6455                    Hard SSD 480GB 25 inches  143.99         0      1298
# 653   Plants Wireless Sensor Monitor for iPhone.   59.95         0  11905404
#
#                                                  category price_category
# 6455  , hard disk drive, storage, second-hand/refurbished         Medium
# 653                    , hard disk drive, monitor, sensor            low

# %% [markdown]
# Here, we can see that **776 categories** have been created. This indicates that the multiple categories approach is not very effective because the number of categories is excessively large, and each product belongs to multiple categories. As a result, products do not fit into a single overarching category, making it better to explore an alternative method.

# %% [markdown]
# ## 4.&nbsp; Using `type` to create categories
# There is another way to create categories. We have the mysterious column `type` in the `products` table. This could potentially be ready-made categories labelled with numbers instead of words. Let's investigate.

# %%
category_type_df = products_cl.copy()

# %% [markdown]
# First, let's see how many `type`s account for most of our products?

# %%
n = 30
print(f"With the {n} largest types, we account for {((category_type_df.groupby('type').count().nlargest(n, 'sku')['sku'].sum()) / (category_type_df.shape[0]) * 100).round(2)}% of all products.")
# Out:
# With the 30 largest types, we account for 78.4% of all products.

# %% [markdown]
# > Looks like we can simply investigate 30 types and set the categories, then the remaining 20% of products can have the category **`other`**.

# %% [markdown]
# Here are the `type`s that have the most products.

# %%
category_type_df.groupby("type").count().nlargest(30, "sku")
# Out:
#            sku  name  desc  price  in_stock
# type
# 11865403  1057  1057  1057   1057      1057
# 12175397   939   939   939    939       939
# 1298       783   783   783    783       783
# 11935397   562   562   562    562       562
# 11905404   454   454   454    454       454
# 1282       373   373   373    373       373
# 12635403   362   362   362    362       362
# 13835403   269   269   269    269       269
# 5,74E+15   247   247   247    247       247
# 1364       216   216   216    216       216
# 12585395   190   190   190    190       190
# 1296       187   187   187    187       187
# 1325       183   183   183    183       183
# 5384       178   178   178    178       178
# 1433       171   171   171    171       171
# 12215397   170   170   170    170       170
# 5398       159   159   159    159       159
# 1,02E+12   130   130   130    130       130
# 1,44E+11   129   129   129    129       129
# 57445397   129   129   129    129       129
# 1334       115   115   115    115       115
# 2158       107   107   107    107       107
# 2449       107   107   107    107       107
# 12655397   105   105   105    105       105
# 1229       104   104   104    104       104
# 12995397    95    95    95     95        95
# 1515        85    85    85     85        85
# 13615399    78    78    78     78        78
# 13555403    75    75    75     75        75
# 1405        75    75    75     75        75

# %% [markdown]
# Let's have a look at the first `type` to see if we can make categories from this column.

# %%
#1. 11865403
category_type_df.loc[category_type_df["type"] == "11865403"].sample(2)
# Out:
#           sku  \
# 1003  LIF0042
# 4524  OTT0132
#
#                                                                                                      name  \
# 1003                                                         LifeProof Fre iPhone 6 Black Waterproof Case
# 4524  OtterBox Symmetry Alpha Glass Case + Screen Protector + Program 1 M ± or guarantee for iPhone 6 ...
#
#                                                                                     desc  \
# 1003                                waterproof and extreme conditions for iPhone 6 case.
# 4524  Pack OtterBox Symmetry Case + Screen Protector + 1 M ± or warranty Black iPhone 6S
#
#       price  in_stock      type
# 1003  79.99         0  11865403
# 4524  49.99         0  11865403

# %%
category_type_df.loc[category_type_df["type"] == "11865403"]['desc'].nunique()
# Out:
# 551

# %% [markdown]
# Let's look at these 551 row with the same type:

# %%
#category_type_df.loc[category_type_df["type"] == "11865403"]["desc"].unique()

# %% [markdown]
# Looks like this is a category of phone cases. Thus, we assign these row to phone cases categories:

# %%
#1. 11865403
category_type_df.loc[category_type_df["type"] == "11865403","category"] = ", iphone case"

# %% [markdown]
# Let's have a look at the 2nd largest type to see if that's also a clear category.

# %%
#2. 12175397
category_type_df.loc[category_type_df["type"] == "12175397"].sample(2)
# Out:
#           sku                                                       name  \
# 9352  PAC2481  Synology DS218 NAS Server | 6TB (2x3TB) Seagate Iron Wolf
# 5919  PAC1750                          QNAP TS-131p | 8TB (1x8TB) WD Red
#
#                                                     desc   price  in_stock  \
# 9352  2-bay NAS server can accommodate 4K Ultra HD files  553.44         0
# 5919   NAS 8TB capacity WD Red Hard Drive for Mac and PC  525.99         0
#
#           type category
# 9352  12175397      NaN
# 5919  12175397      NaN

# %% [markdown]
# Looks like this category is full of servers.

# %%
#2. 12175397
category_type_df.loc[category_type_df["type"] == "12175397",'category'] = ", NAS Server / Network"

# %%
#3. 1298
category_type_df.loc[category_type_df["type"] == "1298"].sample(2)
# Out:
#             sku                                              name  \
# 6199  SAT0018-A  Open - Satechi Aluminum Rose Gold iPhone Support
# 3300  IFX0013-A   (Open) iFixit repair kit complete repair iPhone
#
#                                                                                                desc  \
# 6199  Stand with aluminum finish Lightning access to cable and non-slip surface for iPhone and iPod
# 3300                                                                   Repair Kit tools for iPhone.
#
#       price  in_stock  type category
# 6199  34.99         0  1298      NaN
# 3300  19.99         0  1298      NaN

# %%
#3. 1298
category_type_df.loc[category_type_df["type"] == "1298" , 'category'] = ", open"

# %%
#4. 11935397
category_type_df.loc[category_type_df["type"] == "11935397"].sample(2)
# Out:
#           sku                                                        name  \
# 9658  GTE0131     G-Technology G-SPEED XL 96TB RAID Thunderbolt Shuttle 3
# 5900  WDT0377  WD My Passport 2TB 25 PRO Wireless Wifi USB 3.0 Hard Drive
#
#                                                                                desc  \
# 9658              External Storage 96TB and Thunderbolt 3 Connection for Mac and PC
# 5900  2TB external hard drive with built-in WiFi SD slot and USB 3.0 for Mac and PC
#
#          price  in_stock      type category
# 9658  10212.99         0  11935397      NaN
# 5900    229.99         1  11935397      NaN

# %%
#4. 11935397
category_type_df.loc[category_type_df["type"] == "11935397",'category'] = ', Hard drive'

# %%
#5. 11905404
category_type_df.loc[category_type_df["type"] == "11905404"].sample(2)
# Out:
#           sku  \
# 3436  IKM0049
# 5534  PAR0068
#
#                                                                              name  \
# 3436  IK Multimedia iRig Keys 37 PRO USB MIDI controller for Mac iPhone iPad iPod
# 5534                                                          Mando Parrot FLYPAD
#
#                                                               desc   price  \
# 3436           USB MIDI keyboard 37 keys for Mac iPhone iPad iPod.  121.99
# 5534  Mando compatible with minidrones includes support for iPhone   39.00
#
#       in_stock      type category
# 3436         1  11905404      NaN
# 5534         0  11905404      NaN

# %%
#5. 11905404
category_type_df.loc[category_type_df["type"] == "11905404",'category'] = ', bluetooth device'

# %%
#6. 1282
category_type_df.loc[category_type_df["type"] == "1282"].sample(2)
# Out:
#           sku                                                            name  \
# 2737  APP1198         Apple iMac 27 "Core i5 3.2GHz Retina 5K | 8GB | 1TB HDD
# 1686  APP0958  Apple MacBook Pro Retina 13 "i5 27 Ghz | 8GB RAM | 128GB Flash
#
#                                                                                   desc  \
# 2737             IMac desktop computer 27 inch 5K Retina 8GB RAM 1TB HDD (MK462Y / A).
# 1686  New MacBook Pro 13-inch Retina screen i5 128GB RAM 8GB Flash 27GHz (MF839Y / A).
#
#        price  in_stock  type category
# 2737  2129.0         0  1282      NaN
# 1686  1449.0         0  1282      NaN

# %%
##6. 1282
category_type_df.loc[category_type_df["type"] == "1282",'category'] = ', Apple imac'

# %%
#7. 12635403
category_type_df.loc[category_type_df["type"] == "12635403"].sample(2)
# Out:
#           sku                                    name  \
# 4066  APP1537  Apple iPad Silicone Case Pro 97 "Menta
# 6764  APP2015  Apple iPad Smart Cover Case Blue Night
#
#                                                               desc  price  \
# 4066     Silicone light cover and soft touch for iPad Pro 97-inch.   79.0
# 6764  smart cover with different positions for iPad (2017 Edition)   45.0
#
#       in_stock      type category
# 4066         0  12635403      NaN
# 6764         0  12635403      NaN

# %%
#7. 12635403
category_type_df.loc[category_type_df["type"] == "12635403",'category'] = ', iPad case'

# %%
#8. 13835403
category_type_df.loc[category_type_df["type"] == "13835403"].sample(2)
# Out:
#           sku                                                            name  \
# 4039  MOS0185  ClearGuard Moshi Magic Keyboard Keyboard Protector Transparent
# 4562  SPE0175                 Speck SeeThru Case Macbook Pro 13 "Blue Calypso
#
#                                                         desc  price  in_stock  \
# 4039          Transparent keyboard protector Keyboard Magic.  29.99         0
# 4562  Protective polycarbonate shell for MacBook Pro 13-inch  49.90         0
#
#           type category
# 4039  13835403      NaN
# 4562  13835403      NaN

# %%
#8. 13835403
category_type_df.loc[category_type_df["type"] == "13835403",'category'] = ', macbook case'

# %%
#9. 5,74E+15
category_type_df.loc[category_type_df["type"] == "5,74E+15"].sample(2)
# Out:
#           sku  \
# 2840  PAC0978
# 7319  PAC2126
#
#                                                                                    name  \
# 2840  Apple iMac 27 "Core i5 3.2GHz Retina 5K | 32GB | 512GB Flash | AMD Radeon R9 M390
# 7319                           Apple iMac 27 "Core i5 3.8GHz Retina 5K | 32GB | 1TB SSD
#
#                                                                                                      desc  \
# 2840  IMac desktop computer 27 inch 5K Retina i5 3.2GHz 512GB Flash RAM 32GB and AMD Radeon R9 M390 (M...
# 7319                                        IMac desktop computer 27 inch Retina 5K RAM 32GB SSD 1TB PCle
#
#        price  in_stock      type category
# 2840  3409.0         0  5,74E+15      NaN
# 7319  4039.0         0  5,74E+15      NaN

# %%
#9. 5,74E+15
category_type_df.loc[category_type_df["type"] == "5,74E+15",'category'] = ', Apple iMac 27'

# %%
#10. 1364
category_type_df.loc[category_type_df["type"] == "1364"].sample(2)
# Out:
#             sku                                              name  \
# 1893  FCM0007-4  Mac memory FCM 32GB (4x8GB) SO-DIMM DDR3 1333MHz
# 7936  OWC0191-4        Mac OWC 128GB memory (4x32GB) 1333MHz DIMM
#
#                                        desc    price  in_stock  type category
# 1893       RAM 32GB (4x8GB) iMac (2010/11).   275.96         0  1364      NaN
# 7936  128GB RAM (4x32GB) Mac Pro 2010-2012.  1383.96         0  1364      NaN

# %%
#10. 1364
category_type_df.loc[category_type_df["type"] == "1364",'category'] = ', mac RAM'

# %%
#11. 12585395
category_type_df.loc[category_type_df["type"] == "12585395"].sample(2)
# Out:
#           sku                                         name  \
# 9109  SAT0070  Satechi USB adapter to HDMI 4K-C 60Hz Plata
# 2123  SNN0048   Sonnet Thunderbolt Adapter eSATA + USB 3.0
#
#                                                                  desc   price  \
# 9109                USB-C adapter with HDMI connection for Mac and PC   34.99
# 2123  Thunderbolt adapter with USB 3.0 and eSATA for Mac and PC port.  120.00
#
#       in_stock      type category
# 9109         1  12585395      NaN
# 2123         0  12585395      NaN

# %%
#11. 12585395
category_type_df.loc[category_type_df["type"] == "12585395",'category'] = ', adapter'

# %%
#12. 1296
category_type_df.loc[category_type_df["type"] == "1296"].sample(2)
# Out:
#           sku                                                 name  \
# 5911  LGE0053  34UC79G-B LG Monitor 34 "UHD USB 3.0 HDMI 1ms 144Hz
# 3837  LGE0037             24MP58VQ-W Monitor LG 24 "5ms HDMI White
#
#                                                                           desc  \
# 5911  Monitor 34 for the game 1ms response time 144Hz frequency for Mac and PC
# 3837     24-inch FHD IPS Monitor HDMI connection 5ms response time thin frame.
#
#       price  in_stock  type category
# 5911  599.0         0  1296      NaN
# 3837  159.0         0  1296      NaN

# %%
#12. 1296
category_type_df.loc[category_type_df["type"] == "1296",'category'] = ', monitor'

# %%
#13 1325
category_type_df.loc[category_type_df["type"] == "1325"].sample(2)
# Out:
#           sku                               name  \
# 124   KAN0009  Kanex ATV Pro HDMI to VGA adapter
# 2110  OWC0150  OWC Thunderbolt Cable 2 10m Black
#
#                                           desc   price  in_stock  type  \
# 124   HDMI to VGA adapter that supports audio.   59.95         0  1325
# 2110                   Thunderbolt Cable 2 10m  294.99         0  1325
#
#      category
# 124       NaN
# 2110      NaN

# %%
#13 1325
category_type_df.loc[category_type_df["type"] == "1325",'category'] = ', Cable'

# %%
#14 5384
category_type_df.loc[category_type_df["type"] == "5384"].sample(2)
# Out:
#           sku  \
# 855   JAB0037
# 2363  JAB0044
#
#                                                                  name  \
# 855                             Classic Jabra Bluetooth Headset White
# 2363  Jabra Sport Coach Wireless Headset for iPhone and iPod Amarillo
#
#                                                                     desc  \
# 855                             Bluetooth hands-free headset for iPhone.
# 2363  Headphones and Dolby intelligent voice system for iPhone and iPod.
#
#        price  in_stock  type category
# 855    29.95         0  5384      NaN
# 2363  119.95         0  5384      NaN

# %%
#14 5384
category_type_df.loc[category_type_df["type"] == "5384",'category'] = ', Headphone'

# %%
#15 1433
category_type_df.loc[category_type_df["type"] == "1433"].sample(2)
# Out:
#           sku  \
# 4901  PAC1503
# 4897  PAC1499
#
#                                                                  name  \
# 4901  Crucial MX300 Pack + 1050GB Installation Kit iMac 27 "2012-2015
# 4897         Samsung SSD 850 expansion kit EVO 1TB iMac 27 "2012-2015
#
#                                                             desc   price  \
# 4901       1050GB SSD MX300 + toolkit for 27-inch iMac 2012-2015  373.32
# 4897  SSD upgrade kit 1TB iMac 27-inch Late 2012 Late 2015 tools  469.97
#
#       in_stock  type category
# 4901         1  1433      NaN
# 4897         1  1433      NaN

# %%
#15 1433
category_type_df.loc[category_type_df["type"] == "1433",'category'] = ', SSD expansion kit'

# %%
#16 12215397
category_type_df.loc[category_type_df["type"] == "12215397"].sample(2)
# Out:
#           sku                                                  name  \
# 2186  OWC0156                       Aura OWC 960GB 6G SSD iMac 2012
# 1482  OWC0142  OWC Aura Pro Express 6G - 240GB SSD MacBook Air 2012
#
#                                                desc   price  in_stock  \
# 2186  960GB SSD hard drive for iMac131 and iMac132.  469.99         0
# 1482     240GB SSD hard drive for MacBook Air 2012.  205.99         0
#
#           type category
# 2186  12215397      NaN
# 1482  12215397      NaN

# %%
#16 12215397
category_type_df.loc[category_type_df["type"] == "12215397",'category'] = ', SSD'

# %%
#17 5398
category_type_df.loc[category_type_df["type"] == "5398"].sample(2)
# Out:
#           sku                                           name  \
# 2079  BOS0021              Bose SoundLink Color Speaker Mint
# 4747  JBL0112  Charge 3 JBL Bluetooth Portable Speaker Black
#
#                                                                  desc   price  \
# 2079             Bluetooth wireless speaker for iPhone iPad and iPod.  139.00
# 4747  Bluetooth portable speaker waterproof for iPhone iPad and iPod.  169.99
#
#       in_stock  type category
# 2079         0  5398      NaN
# 4747         1  5398      NaN

# %%
#17 5398
category_type_df.loc[category_type_df["type"] == "5398",'category'] = ', Speaker'

# %%
#18 1,02E+12
category_type_df.loc[category_type_df["type"] == "1,02E+12"].sample(2)
# Out:
#           sku  \
# 7372  APP2292
# 7367  APP2288
#
#                                                                         name  \
# 7372  Apple MacBook Pro 13 "Core i5 Touch Bar 33GHz | 8GB | 256GB SSD Silver
# 7367    Apple MacBook Pro 13 "Core i7 Touch Bar 35GHz | 8GB | 1TB SSD Silver
#
#                                                                                      desc  \
# 7372  New MacBook Pro 13 inch Touch Bar 33 GHz Core i5 with 8GB of RAM and 256GB PCIe SSD
# 7367    New MacBook Pro 13 inch Touch Bar 35 GHz Core i7 with 8GB of RAM and 1TB PCIe SSD
#
#        price  in_stock      type category
# 7372  2119.0         0  1,02E+12      NaN
# 7367  3109.0         0  1,02E+12      NaN

# %%
#18 1,02E+12
category_type_df.loc[category_type_df["type"] == "1,02E+12",'category'] = ', Apple MacBook Pro 13/15'

# %%
#19 1,44E+11
category_type_df.loc[category_type_df["type"] == "1,44E+11"].sample(2)
# Out:
#           sku                          name  \
# 6561  REP0360  LCD screen repair iPad Air 2
# 240   REP0099    iPad 3 front camera repair
#
#                                                          desc   price  \
# 6561  Repair service including parts and labor for iPad Air 2  299.99
# 240       Repair service including parts and labor for iPad 3   69.99
#
#       in_stock      type category
# 6561         0  1,44E+11      NaN
# 240          0  1,44E+11      NaN

# %%
#19 1,44E+11
category_type_df.loc[category_type_df["type"] == "1,44E+11",'category'] = ', service'

# %%
#20 57445397
category_type_df.loc[category_type_df["type"] == "57445397"].sample(2)
# Out:
#           sku                                                name  \
# 3733  LEX0029  Lexar jumpdrive M20C PenDrive USB-C / USB 3.0 16GB
# 3431  KIN0148      Kingston SDXC Memory Card UHS Class 3 | 128 GB
#
#                                                                desc  price  \
# 3733      USB flash drive-C reversible USB 3.0 16GB for Mac and PC.  20.99
# 3431  SDXC Memory Card UHS Class 3 128GB with speeds of 90MB / 80MB  59.99
#
#       in_stock      type category
# 3733         0  57445397      NaN
# 3431         0  57445397      NaN

# %%
#20 57445397
category_type_df.loc[category_type_df["type"] == "57445397",'category'] = ', Memory Card'

# %%
#21 1334
category_type_df.loc[category_type_df["type"] == "1334"].sample(2)
# Out:
#           sku                                                    name  \
# 478   DLK0044  D-Link DIR-860L Wireless AC1200 Dual-Band Cloud Router
# 3522  DLK0118       D-Link DWA-182 USB Adapter Wi-Fi AC1200 Dual-Band
#
#                                                                            desc  \
# 478   Wireless Router DLink Cloud with AC SmartBeam and 867 Mbps transfer rate.
# 3522                          Wi-Fi USB adapter AC 5G dual-band for Mac and PC.
#
#        price  in_stock  type category
# 478   129.99         0  1334      NaN
# 3522   59.99         0  1334      NaN

# %%
#21 1334
category_type_df.loc[category_type_df["type"] == "1334",'category'] = ', Router'

# %%
#22 2158
category_type_df.loc[category_type_df["type"] == "2158"].sample(2)
# Out:
#           sku  \
# 5997  APP1958
# 5645  APP1881
#
#                                                                                                      name  \
# 5997                            Apple MacBook Pro 13 "Core i5 2GHz | RAM 16GB | 512GB PCIe SSD Gray Space
# 5645  Apple MacBook Pro 15 "Core i7 Touch Bar 26GHz | 16GB RAM | 1TB PCIe SSD | 460 4GB Radeon Pro Spa...
#
#                                                                                                    desc  \
# 5997                               MacBook Pro 13 inch i5 2GHz RAM 16GB SSD and 512GB PCIe (MLL42Y / A)
# 5645  New MacBook Pro 15-inch Touch Bar to 26GHz Core i7 with 16GB of RAM and 1TB PCIe SSD (MLH32Y / A)
#
#        price  in_stock  type category
# 5997  2179.0         0  2158      NaN
# 5645  3659.0         0  2158      NaN

# %%
#22 2158
category_type_df.loc[category_type_df["type"] == "2158",'category'] = ', Apple MacBook Pro'

# %%
#23. 2449
category_type_df.loc[category_type_df["type"] == "2449"].sample(2)
# Out:
#           sku                                             name  \
# 3323  CYG0073     Cygnett Luxband Apple Watch Strap Black 42mm
# 3538  BAN0008  Panama Band & Strap Watch Strap 42mm Blue Apple
#
#                                                        desc  price  in_stock  \
# 3323  Leather strap for easy installation Apple Watch 42mm.  49.99         0
# 3538  Leather strap for easy installation Apple Watch 42mm.  59.00         0
#
#       type category
# 3323  2449      NaN
# 3538  2449      NaN

# %%
#23. 2449
category_type_df.loc[category_type_df["type"] == "2449",'category'] = ', Apple Watch Strap'

# %%
#24 12655397
category_type_df.loc[category_type_df["type"] == "12655397"].sample(2)
# Out:
#           sku                                   name  \
# 3944  WDT0316  Blue WD Hard Drive 1TB 35 "Mac and PC
# 9951  WDT0417     WD Hard Drive 6TB Gold 35 "Servers
#
#                                                                                              desc  \
# 3944                  Western Digital Internal Hard Drive 1TB Sata 6GBs 35 inches for Mac and PC.
# 9951  Hard Western Digital 6TB 35 inches SATA 6 Gb / s for servers and enterprise storage systems
#
#       price  in_stock      type category
# 3944   65.0         1  12655397      NaN
# 9951  329.0         0  12655397      NaN

# %%
#24 12655397
category_type_df.loc[category_type_df["type"] == "12655397",'category'] = ', Hard Drive'

# %%
#25 1229
category_type_df.loc[category_type_df["type"] == "1229"].sample(2)
# Out:
#           sku                                         name  \
# 9895  ADN0060  Adonith Stylus Pro Pointer Gray Pixel Space
# 76    WAC0046               Intuos Wacom stylus ArtPen 5/4
#
#                                                             desc   price  \
# 9895                 Bluetooth digital pen tip 19mm Pro for iPad   84.99
# 76    special stylus Mac and PC for Intuos4 graphics tablet / 5.  109.90
#
#       in_stock  type category
# 9895         1  1229      NaN
# 76           0  1229      NaN

# %%
#25 1229
category_type_df.loc[category_type_df["type"] == "1229",'category'] = ', pointer'

# %%
#26 12995397
category_type_df.loc[category_type_df["type"] == "12995397"].sample(2)
# Out:
#           sku                                                   name  \
# 8322  OWC0234  OWC USB Travel Dock-C / USB 3.1 / HDMI / SD Card Gold
# 9203  SNN0069  Sonnet eGFX Breakaway Puck Radeon RX560 Thunderbolt 3
#
#                                                                   desc  \
# 8322            Dock USB-C multiple connections and SD reader Macbook.
# 9203  Box Portable expansion graphics cards with Radeon RX560 included
#
#        price  in_stock      type category
# 8322   66.99         0  12995397      NaN
# 9203  699.99         0  12995397      NaN

# %%
#26 12995397
category_type_df.loc[category_type_df["type"] == "12995397",'category'] = ', Thunderbolt/ports'

# %%
#27 1515
category_type_df.loc[category_type_df["type"] == "1515"].sample(2)
# Out:
#           sku                                                       name  \
# 6015  XOO0011             Xoopar SQUID MAX External Battery 2500mAh Gray
# 9207  HTE0021  Hyper Pearl 1600mAh battery Mini USB Mirror and Ice Cream
#
#                                                                     desc  \
# 6015   Lightning external battery cable and grip suction cups for iPhone
# 9207  Mini Portable USB Mirror + 1600mAh (2.1A) battery cable for iPhone
#
#       price  in_stock  type category
# 6015  24.99         0  1515      NaN
# 9207  24.99         1  1515      NaN

# %%
#27 1515
category_type_df.loc[category_type_df["type"] == "1515",'category'] = ', battery'

# %%
#28 13615399
category_type_df.loc[category_type_df["type"] == "13615399"].sample(2)
# Out:
#           sku                                              name  \
# 4119  PAC1395  MIXIT Pack Belkin Car Charger and house 24A Gray
# 9301  TWS0124               Twelve South HiRise based load Duet
#
#                                                                    desc  \
# 4119  Metallic car charger + wall charger 24A for iPad iPhone and iPad.
# 9301  Stand with Lightning connector and charger for Apple iPhone Watch
#
#        price  in_stock      type category
# 4119   34.98         1  13615399      NaN
# 9301  129.99         1  13615399      NaN

# %%
#28 13615399
category_type_df.loc[category_type_df["type"] == "13615399",'category'] = ', Charger'

# %%
#29 13555403
category_type_df.loc[category_type_df["type"] == "13555403"].sample(2)
# Out:
#           sku                                                          name  \
# 300   MOS0086          Moshi iVisor XT protector iPhone / 5s / 5c / 5 black
# 5447  ZAG0029  Zagg Invisible Shield Glass Screen Protector iPhone 8/7 Plus
#
#                                                                                desc  \
# 300                                        IPhone Protector SE / 5s / 5 anti glare.
# 5447  Protector Ultra soft edges beveled tempered glass for iPhone 8 Plus or 7-Plus
#
#       price  in_stock      type category
# 300   24.95         0  13555403      NaN
# 5447  19.99         0  13555403      NaN

# %%
#29 13555403
category_type_df.loc[category_type_df["type"] == "13555403",'category'] = ', Screen protector'

# %%
#30 1405
category_type_df.loc[category_type_df["type"] == "1405"].sample(2)
# Out:
#           sku                                            name  \
# 6260  WAC0225            Education - Wacom Intuos Pro L South
# 471   WAC0133  Education - Wacom Intuos Pro M Graphics Tablet
#
#                                                                                                      desc  \
# 6260  Large graphics tablet includes Bluetooth Intuos Pro Pen Pointer 2 (8192 levels of pressure) for ...
# 471                                                         Exclusive discount for students and teachers.
#
#        price  in_stock  type category
# 6260  529.90         0  1405      NaN
# 471   349.99         0  1405      NaN

# %%
#30 1405
category_type_df.loc[category_type_df["type"] == "1405",'category'] = ', Graphic tablet/pen'

# %%
category_type_df.loc[category_type_df["category"] == "", 'category'] = 'other'

# %%
category_type_df.groupby("type").count().nlargest(30, "sku")
# Out:
#            sku  name  desc  price  in_stock  category
# type
# 11865403  1057  1057  1057   1057      1057      1057
# 12175397   939   939   939    939       939       939
# 1298       783   783   783    783       783       783
# 11935397   562   562   562    562       562       562
# 11905404   454   454   454    454       454       454
# 1282       373   373   373    373       373       373
# 12635403   362   362   362    362       362       362
# 13835403   269   269   269    269       269       269
# 5,74E+15   247   247   247    247       247       247
# 1364       216   216   216    216       216       216
# 12585395   190   190   190    190       190       190
# 1296       187   187   187    187       187       187
# 1325       183   183   183    183       183       183
# 5384       178   178   178    178       178       178
# 1433       171   171   171    171       171       171
# 12215397   170   170   170    170       170       170
# 5398       159   159   159    159       159       159
# 1,02E+12   130   130   130    130       130       130
# 1,44E+11   129   129   129    129       129       129
# 57445397   129   129   129    129       129       129
# 1334       115   115   115    115       115       115
# 2158       107   107   107    107       107       107
# 2449       107   107   107    107       107       107
# 12655397   105   105   105    105       105       105
# 1229       104   104   104    104       104       104
# 12995397    95    95    95     95        95        95
# 1515        85    85    85     85        85        85
# 13615399    78    78    78     78        78        78
# 13555403    75    75    75     75        75        75
# 1405        75    75    75     75        75        75

# %%
category_type_df.sample(5)
# Out:
#           sku                                                      name  \
# 2598  NTE0100  NewerTech Guardian Maximus RAID mini FW800 / eSATA / USB
# 6812  HOC0008      Nike hoco Series Apple Watch Strap 42mm Black / Gray
# 7636  PAC1941   Apple Mac Pro 35GHz 6 cores | 32GB RAM | 256GB PCIe SSD
# 5556  IKM0062            IK Multimedia iRig Guitar Interface 96kHz HD 2
# 4997  BEL0265      InvisiGlass Belkin Screen Protector Apple Watch 42mm
#
#                                                                                                      desc  \
# 2598                                 Mini Raid system with FW800 / eSATA / USB connection for Mac and PC.
# 6812                                                               Silicone Strap Sports Watch 42mm Apple
# 7636                     New Mac Pro with 32GB RAM and two 6-core GPU 35GHz AMD FirePro D500 (MD878Y / A)
# 5556  Guitar interface for recording high quality audio 24bit / 96kHz compatible headphone amplifier p...
# 4997     Tempered glass protector with ultrafine thickness 02 mm and FluidFlex technology for Apple Watch
#
#         price  in_stock      type             category
# 2598   120.99         0  11935397         , Hard drive
# 6812    45.00         0      2449  , Apple Watch Strap
# 7636  3935.59         0  21632158                  NaN
# 5556   121.99         1  11905404   , bluetooth device
# 4997    19.99         1      2425                  NaN

# %% [markdown]
# After creating categories we can write all of our category creation code in a single function. It will help us keep things organized.

# %% [markdown]
# ## 5.&nbsp; Writing a function to create categories

# %%
product_category_type_df = products_cl.copy()

# %% [markdown]
# We use a dictionary to map each type to an already defined category:

# %%
type_dict = {
    '5,74E+15':'Apple iMac 27',
    '1,02E+12':'Apple Macbook Pro 13/15',
    '1282':'Apple iMac',
    '11935397':'Hard drive',
    '1296':'Monitor',
    '12175397':'NAS Server / Network',
    '2,17E+11':'(Open) Apple Macbook Pro 13/ 15',
    '12215397':'SSD',
    '1405':'graphic tablet',
    '2,16E+11':'Apple iMac 21.5',
    '1364':'mac RAM',
    '12655397':'Mac PC Hard Drive',
    '2158':'Apple MacBook Pro',
    '51601716':'(Open) Apple iPhone',
    '11905404':'bluetooth device',
    '113281716':'Apple iPhone 8 Plus',
    '5384':'Headphones',
    '113291716':'Apple iPhone 8',
    '85641716':'Apple iPhone 7',
    '85651716':'Apple iPhone 7 Plus',
    '106431714':'Apple iPad 64gb',
    '1433':'SSD',
    '24895185':'Apple Watch',
    '1298':'Open',
    '5398':'speaker',
    '1714':'iPad',
    '113271716':'Apple iPhone X',
    '21561716':'Apple iPhone 6',
    '12585395':'Adapter',
    '11865403':'iPhone case',
    '1231':'Service',
    '21632158':'mac',
    '5,39E+11':'macbook',
    '12995397':'thunderbolt',
    '10142':'battery',
    '13855401':'keyboard',
    '51861714':'iPad pro 256gb',
    '24821716':'iphone 6s',
    '118692158':'imac',
    '13005399':'macbook charger',
    '24885185':'apple watch',
    '1229':'pointer',
    '42945397':'lightning usb',
    '12635403':'iPad case',
    '51871714':'ipad',
    '1334':'router',
    '57445397':'memory card',
    '1325':'cable',
    '1387':'mouse',
    '13835403':'macbook case',
    '2449':'Apple Watch Strap'
}
product_category_type_df['category'] = product_category_type_df['type'].map(type_dict)
product_category_type_df.loc[product_category_type_df['category'].isna(),'category'] = 'other'

# %%
product_category_type_df.sample(2)
# Out:
#           sku                                     name  \
# 1624  RAI0018  Rain Design Mbase Support for iMac 27 "
# 6787  WAC0240   Education - Wacom Bamboo A5 Slate Gray
#
#                                                                      desc  \
# 1624                            Minimalist support lifting drawer iMac 27
# 6787  Bloc notes A5 size smart app includes pen button to save your notes
#
#        price  in_stock  type        category
# 1624   84.99         1  8696           other
# 6787  129.99         0  1405  graphic tablet

# %%
product_category_type_df['category'].value_counts(dropna=False)
# Out:
# category
# other                              1711
# iPhone case                        1057
# NAS Server / Network                939
# Open                                783
# Hard drive                          562
# bluetooth device                    454
# Apple iMac                          373
# iPad case                           362
# SSD                                 341
# macbook case                        269
# Apple iMac 27                       247
# mac RAM                             216
# Adapter                             190
# Monitor                             187
# cable                               183
# Headphones                          178
# speaker                             159
# Apple Macbook Pro 13/15             130
# memory card                         129
# router                              115
# Apple Watch Strap                   107
# Apple MacBook Pro                   107
# Mac PC Hard Drive                   105
# pointer                             104
# thunderbolt                          95
# graphic tablet                       75
# imac                                 72
# Apple Watch                          67
# apple watch                          67
# macbook                              47
# lightning usb                        44
# (Open) Apple iPhone                  43
# Apple iMac 21.5                      42
# Apple iPhone 7 Plus                  42
# macbook charger                      37
# mac                                  37
# (Open) Apple Macbook Pro 13/ 15      36
# keyboard                             34
# Apple iPhone 7                       32
# Apple iPad 64gb                      29
# iPad pro 256gb                       28
# iPad                                 28
# mouse                                23
# battery                              23
# iphone 6s                            20
# Apple iPhone 8 Plus                  16
# ipad                                 15
# Apple iPhone 8                       13
# Service                              10
# Apple iPhone 6                        5
# Apple iPhone X                        4
# Name: count, dtype: int64

# %% [markdown]
# We can also be more specific and define higher-level categories:

# %%
# Create a dictionary to map product types to a higher-level category
category_mapping = {
    '5,74E+15': 'Apple iMac',
    '1,02E+12': 'Apple Macbook',
    '1282': 'Apple iMac',
    '11935397': 'Memory Storage',
    '1296': 'Monitor',
    '12175397': 'Network',
    '2,17E+11': 'Apple Macbook',
    '12215397': 'Memory Storage',
    '1405': 'Graphics Tablet',
    '2,16E+11': 'Apple iMac',
    '1364': 'Memory Storage',
    '12655397': 'Memory Storage',
    '2158': 'Apple Macbook Pro',
    '51601716': 'Second hand',
    '11905404': 'Accessories',
    '113281716': 'Apple iPhone',
    '5384': 'Headphones',
    '113291716': 'Apple iPhone',
    '85641716': 'Apple iPhone',
    '85651716': 'Apple iPhone',
    '106431714': 'Apple iPad',
    '1433': 'Memory Storage',
    '24895185': 'Apple Watch',
    '1298': 'Second hand',
    '5398': 'Speakers',
    '1714': 'Apple iPad',
    '113271716': 'Apple iPhone',
    '21561716': 'Apple iPhone',
    '12585395': 'Accessories',
    '11865403': 'Accessories',
    '1231': 'Service',
    '21632158': 'Apple Macbook',
    '5,39E+11': 'Apple Macbook',
    '12995397': 'Accessories',
    '10142': 'Accessories',
    '13855401': 'Accessories',
    '51861714': 'Apple iPad',
    '24821716': 'Apple iPhone',
    '118692158': 'Apple iMac',
    '13005399': 'Accessories',
    '24885185': 'Apple Watch',
    '1229': 'Accessories',
    '42945397': 'Accessories',
    '12635403': 'Accessories',
    '51871714': 'Apple iPad',
    '1334': 'Network',
    '57445397': 'Memory Storage',
    '1325': 'Accessories',
    '1387': 'Accessories',
    '13835403': 'Accessories',
    '2449': 'Accessories'
}

# Apply the mapping to create the new 'category_level' column
product_category_type_df['category_level'] = product_category_type_df['type'].map(category_mapping)

# Fill missing values with 'Other'
product_category_type_df['category_level'] = product_category_type_df['category_level'].fillna('Other')

# %%
product_category_type_df.sample(2)
# Out:
#             sku  \
# 6793  OTT0137-A
# 864     GTE0039
#
#                                                                       name  \
# 6793  Open - Otterbox Clearly Protected gel Case iPhone 6 / 6S Transparent
# 864                   G-Tech G-Speed ​​Studio 16TB Disk RAID Thunderbolt 2
#
#                                                                          desc  \
# 6793    transparent cover and a flexible piece TPU for iPhone 6 and iPhone 6s
# 864   Disk RAID Technology G-4 bay thunderbolt2 transfer rate up 700åÊMB / s.
#
#         price  in_stock      type    category  category_level
# 6793    19.99         0      1298        Open     Second hand
# 864   2600.88         0  11935397  Hard drive  Memory Storage

# %% [markdown]
# ## 6.&nbsp; Save the categorized products DataFrame
# Do not forget to download your categorized products DataFrames

# %%
#files.download("products_cl.csv")
product_category_type_df.to_csv("product_category_qu.csv", index=False)
